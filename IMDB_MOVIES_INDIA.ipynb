# %%
import  pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-f2228a1f-f3ea-41f4-83f5-eca15c954dc1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f2228a1f-f3ea-41f4-83f5-eca15c954dc1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IMDb Movies India.csv to IMDb Movies India.csv

# %%
movie=pd.read_csv('IMDb Movies India.csv',encoding='ISO-8859-1')
movie.head()
# Out:
#                                  Name  ...          Actor 3
# 0                                      ...  Rajendra Bhatia
# 1  #Gadhvi (He thought he was Gandhi)  ...    Arvind Jangid
# 2                         #Homecoming  ...       Roy Angana
# 3                             #Yaaram  ...  Siddhant Kapoor
# 4                   ...And Once Again  ...      Antara Mali
#
# [5 rows x 10 columns]

# %%
movie.shape
# Out:
# (15509, 10)

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
movie['Rating'].fillna (value= movie['Rating'].mean(),inplace = True)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    15509 non-null  float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
x = movie["Votes"].mode()[0]

movie["Votes"].fillna(x, inplace = True)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    15509 non-null  float64
#  5   Votes     15509 non-null  object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
movie['Genre'].fillna (value= movie['Genre'].mode()[0],inplace = True)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     15509 non-null  object
#  4   Rating    15509 non-null  float64
#  5   Votes     15509 non-null  object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
from sklearn.preprocessing import StandardScaler
SC=StandardScaler()

# %%
x = movie.loc[:,movie.columns != 'Actor 3' ]
x.head()
# Out:
#                                  Name  ... Genre_War
# 0                                      ...         0
# 1  #Gadhvi (He thought he was Gandhi)  ...         0
# 2                         #Homecoming  ...         0
# 3                             #Yaaram  ...         0
# 4                   ...And Once Again  ...         0
#
# [5 rows x 672 columns]

# %%
x = movie.loc[:,movie.columns != 'Actor 1' ]
x.head()
# Out:
#                                  Name  ... Genre_War
# 0                                      ...         0
# 1  #Gadhvi (He thought he was Gandhi)  ...         0
# 2                         #Homecoming  ...         0
# 3                             #Yaaram  ...         0
# 4                   ...And Once Again  ...         0
#
# [5 rows x 672 columns]

# %%
x = movie.loc[:,movie.columns != 'Genre ' ]
x.head()
# Out:
#                                  Name  ... Genre_War
# 0                                      ...         0
# 1  #Gadhvi (He thought he was Gandhi)  ...         0
# 2                         #Homecoming  ...         0
# 3                             #Yaaram  ...         0
# 4                   ...And Once Again  ...         0
#
# [5 rows x 673 columns]
